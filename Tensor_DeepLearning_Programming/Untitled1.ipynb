# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os

import xml.etree.ElementTree as ET
import cv2

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dropout, MaxPooling2D
from tensorflow.keras.optimizers import Adam

# %%
def getBB(file_path):
    try:
        tree = ET.parse(file_path)
    except FileNotFoundError:
        return None
    root = tree.getroot()
    ob = root.find('object')
    bndbox = ob.find('bndbox')
    xmin = bndbox.find('xmin').text
    xmax = bndbox.find('xmax').text
    ymin = bndbox.find('ymin').text
    ymax = bndbox.find('ymax').text
    
    return [int(xmin), int(ymin), int(xmax), int(ymax)]

# %%
getBB('./annotations/xmls/Abyssinian_1.xml')
# Out:
# [333, 72, 425, 158]

# %%
def load_oxford_pets_3(target_size = (224,224)):
    input_file = './annotations/list.txt'
    file = open(input_file)
    list_txt = file.readlines()
    file.close()
    list_txt = list_txt[6:]

    np.random.shuffle(list_txt)
    
    train_dataset = {'name':[], 'label':[], 'image':[],'box':[]}
    test_dataset = {'name':[], 'label':[],'image':[]}
    
    for line in list_txt:
        image_name, class_id, species, breed_id = line.split()
        image_file = './images/images/' + image_name + '.jpg'
        box_file = './annotations/xmls/' + image_name + '.xml'
        
        print(image_file)
        print(box_file)
        return None
    
        if not os.path.exists(image_file):
            continue
        
        img = image.load_img(image_file)
        sx = target_size[0] / img.width
        sy = target_size[1] / img.height
        
        img = img.resize(size = target_size)
        img = image.img_to_array(img)
        
        if os.path.exists(box_file):
            box = getBB(box_file)
            box[0] = round(box[0] * sx)
            box[1] = round(box[1] * sy)
            box[2] = round(box[2] * sx)
            box[3] = round(box[3] * sy)
            train_dataset['box'].append(box)
            train_dataset['name'].append(image_name)
            train_dataset['label'].append(int(species)-1)
            train_dataset['image'].append(img)
        
        else:
            test_dataset['name'].append(image_name)
            test_dataset['label'].append(int(species)-1)
            test_dataset['image'].append(img)
    
    train_dataset['image'] = np.array(train_dataset['image'])
    train_dataset['box'] = np.array(train_dataset['box'])
    train_dataset['label'] = np.array(train_dataset['label'])
    train_dataset['name'] = np.array(train_dataset['name'])
    
    test_dataset['image'] = np.array(test_dataset['image'])
    test_dataset['label'] = np.array(test_dataset['label'])
    test_dataset['name'] = np.array(test_dataset['name'])
    
    return train_dataset, test_dataset

# %%
x = load_oxford_pets_3()
# Out:
# ./images/images/Persian_155.jpg
# ./annotations/xmls/Persian_155.xml

# %%
x
# Out:
# ['Abyssinian_100 1 1 1\n',
#  'Abyssinian_101 1 1 1\n',
#  'Abyssinian_102 1 1 1\n',
#  'Abyssinian_103 1 1 1\n',
#  'Abyssinian_104 1 1 1\n',
#  'Abyssinian_105 1 1 1\n',
#  'Abyssinian_106 1 1 1\n',
#  'Abyssinian_107 1 1 1\n',
#  'Abyssinian_108 1 1 1\n',
#  'Abyssinian_109 1 1 1\n',
#  'Abyssinian_10 1 1 1\n',
#  'Abyssinian_110 1 1 1\n',
#  'Abyssinian_111 1 1 1\n',
#  'Abyssinian_112 1 1 1\n',
#  'Abyssinian_113 1 1 1\n',
#  'Abyssinian_114 1 1 1\n',
#  'Abyssinian_115 1 1 1\n',
#  'Abyssinian_116 1 1 1\n',
#  'Abyssinian_117 1 1 1\n',
#  'Abyssinian_118 1 1 1\n',
#  'Abyssinian_119 1 1 1\n',
#  'Abyssinian_11 1 1 1\n',
#  'Abyssinian_120 1 1 1\n',
#  'Abyssinian_121 1 1 1\n',
#  'Abyssinian_122 1 1 1\n',
#  'Abyssinian_123 1 1 1\n',
#  'Abyssinian_124 1 1 1\n',
#  'Abyssinian_125 1 1 1\n',
#  'Abyssinian_126 1 1 1\n',
#  'Abyssinian_127 1 1 1\n',
#  'Abyssinian_128 1 1 1\n',
#  'Abyssinian_129 1 1 1\n',
#  'Abyssinian_12 1 1 1\n',
#  'Abyssinian_130 1 1 1\n',
#  'Abyssinian_131 1 1 1\n',
#  'Abyssinian_132 1 1 1\n',
#  'Abyssinian_133 1 1 1\n',
#  'Abyssinian_134 1 1 1\n',
#  'Abyssinian_135 1 1 1\n',
#  'Abyssinian_136 1 1 1\n',
#  'Abyssinian_137 1 1 1\n',
#  'Abyssinian_138 1 1 1\n',
#  'Abyssinian_139 1 1 1\n',
#  'Abyssinian_13 1 1 1\n',
#  'Abyssinian_140 1 1 1\n',
#  'Abyssinian_141 1 1 1\n',
#  'Abyssinian_142 1 1 1\n',
#  'Abyssinian_143 1 1 1\n',
#  'Abyssinian_144 1 1 1\n',
#  'Abyssinian_145 1 1 1\n',
#  'american_bulldog_100 2 2 1\n',
#  'american_bulldog_101 2 2 1\n',
#  'american_bulldog_102 2 2 1\n',
#  'american_bulldog_103 2 2 1\n',
#  'american_bulldog_104 2 2 1\n',
#  'american_bulldog_105 2 2 1\n',
#  'american_bulldog_106 2 2 1\n',
#  'american_bulldog_107 2 2 1\n',
#  'american_bulldog_108 2 2 1\n',
#  'american_bulldog_109 2 2 1\n',
#  'american_bulldog_10 2 2 1\n',
#  'american_bulldog_110 2 2 1\n',
#  'american_bulldog_111 2 2 1\n',
#  'american_bulldog_112 2 2 1\n',
#  'american_bulldog_113 2 2 1\n',
#  'american_bulldog_114 2 2 1\n',
#  'american_bulldog_115 2 2 1\n',
#  'american_bulldog_116 2 2 1\n',
#  'american_bulldog_117 2 2 1\n',
#  'american_bulldog_118 2 2 1\n',
#  'american_bulldog_119 2 2 1\n',
#  'american_bulldog_11 2 2 1\n',
#  'american_bulldog_120 2 2 1\n',
#  'american_bulldog_121 2 2 1\n',
#  'american_bulldog_122 2 2 1\n',
#  'american_bulldog_123 2 2 1\n',
#  'american_bulldog_124 2 2 1\n',
#  'american_bulldog_125 2 2 1\n',
#  'american_bulldog_126 2 2 1\n',
#  'american_bulldog_127 2 2 1\n',
#  'american_bulldog_128 2 2 1\n',
#  'american_bulldog_129 2 2 1\n',
#  'american_bulldog_12 2 2 1\n',
#  'american_bulldog_130 2 2 1\n',
#  'american_bulldog_131 2 2 1\n',
#  'american_bulldog_132 2 2 1\n',
#  'american_bulldog_133 2 2 1\n',
#  'american_bulldog_134 2 2 1\n',
#  'american_bulldog_135 2 2 1\n',
#  'american_bulldog_136 2 2 1\n',
#  'american_bulldog_137 2 2 1\n',
#  'american_bulldog_138 2 2 1\n',
#  'american_bulldog_139 2 2 1\n',
#  'american_bulldog_13 2 2 1\n',
#  'american_bulldog_140 2 2 1\n',
#  'american_bulldog_141 2 2 1\n',
#  'american_bulldog_142 2 2 1\n',
#  'american_bulldog_143 2 2 1\n',
#  'american_bulldog_144 2 2 1\n',
#  'american_bulldog_146 2 2 1\n',
#  'american_pit_bull_terrier_100 3 2 2\n',
#  'american_pit_bull_terrier_101 3 2 2\n',
#  'american_pit_bull_terrier_102 3 2 2\n',
#  'american_pit_bull_terrier_103 3 2 2\n',
#  'american_pit_bull_terrier_104 3 2 2\n',
#  'american_pit_bull_terrier_105 3 2 2\n',
#  'american_pit_bull_terrier_106 3 2 2\n',
#  'american_pit_bull_terrier_107 3 2 2\n',
#  'american_pit_bull_terrier_108 3 2 2\n',
#  'american_pit_bull_terrier_109 3 2 2\n',
#  'american_pit_bull_terrier_10 3 2 2\n',
#  'american_pit_bull_terrier_110 3 2 2\n',
#  'american_pit_bull_terrier_111 3 2 2\n',
#  'american_pit_bull_terrier_112 3 2 2\n',
#  'american_pit_bull_terrier_113 3 2 2\n',
#  'american_pit_bull_terrier_114 3 2 2\n',
#  'american_pit_bull_terrier_115 3 2 2\n',
#  'american_pit_bull_terrier_116 3 2 2\n',
#  'american_pit_bull_terrier_117 3 2 2\n',
#  'american_pit_bull_terrier_118 3 2 2\n',
#  'american_pit_bull_terrier_119 3 2 2\n',
#  'american_pit_bull_terrier_11 3 2 2\n',
#  'american_pit_bull_terrier_120 3 2 2\n',
#  'american_pit_bull_terrier_121 3 2 2\n',
#  'american_pit_bull_terrier_122 3 2 2\n',
#  'american_pit_bull_terrier_123 3 2 2\n',
#  'american_pit_bull_terrier_124 3 2 2\n',
#  'american_pit_bull_terrier_125 3 2 2\n',
#  'american_pit_bull_terrier_126 3 2 2\n',
#  'american_pit_bull_terrier_127 3 2 2\n',
#  'american_pit_bull_terrier_128 3 2 2\n',
#  'american_pit_bull_terrier_129 3 2 2\n',
#  'american_pit_bull_terrier_12 3 2 2\n',
#  'american_pit_bull_terrier_130 3 2 2\n',
#  'american_pit_bull_terrier_131 3 2 2\n',
#  'american_pit_bull_terrier_132 3 2 2\n',
#  'american_pit_bull_terrier_133 3 2 2\n',
#  'american_pit_bull_terrier_134 3 2 2\n',
#  'american_pit_bull_terrier_135 3 2 2\n',
#  'american_pit_bull_terrier_136 3 2 2\n',
#  'american_pit_bull_terrier_137 3 2 2\n',
#  'american_pit_bull_terrier_138 3 2 2\n',
#  'american_pit_bull_terrier_139 3 2 2\n',
#  'american_pit_bull_terrier_13 3 2 2\n',
#  'american_pit_bull_terrier_140 3 2 2\n',
#  'american_pit_bull_terrier_141 3 2 2\n',
#  'american_pit_bull_terrier_142 3 2 2\n',
#  'american_pit_bull_terrier_143 3 2 2\n',
#  'american_pit_bull_terrier_144 3 2 2\n',
#  'american_pit_bull_terrier_145 3 2 2\n',
#  'basset_hound_100 4 2 3\n',
#  'basset_hound_101 4 2 3\n',
#  'basset_hound_102 4 2 3\n',
#  'basset_hound_103 4 2 3\n',
#  'basset_hound_104 4 2 3\n',
#  'basset_hound_105 4 2 3\n',
#  'basset_hound_106 4 2 3\n',
#  'basset_hound_107 4 2 3\n',
#  'basset_hound_108 4 2 3\n',
#  'basset_hound_109 4 2 3\n',
#  'basset_hound_10 4 2 3\n',
#  'basset_hound_110 4 2 3\n',
#  'basset_hound_111 4 2 3\n',
#  'basset_hound_112 4 2 3\n',
#  'basset_hound_113 4 2 3\n',
#  'basset_hound_114 4 2 3\n',
#  'basset_hound_115 4 2 3\n',
#  'basset_hound_116 4 2 3\n',
#  'basset_hound_117 4 2 3\n',
#  'basset_hound_118 4 2 3\n',
#  'basset_hound_119 4 2 3\n',
#  'basset_hound_11 4 2 3\n',
#  'basset_hound_120 4 2 3\n',
#  'basset_hound_121 4 2 3\n',
#  'basset_hound_122 4 2 3\n',
#  'basset_hound_123 4 2 3\n',
#  'basset_hound_124 4 2 3\n',
#  'basset_hound_125 4 2 3\n',
#  'basset_hound_126 4 2 3\n',
#  'basset_hound_127 4 2 3\n',
#  'basset_hound_128 4 2 3\n',
#  'basset_hound_129 4 2 3\n',
#  'basset_hound_12 4 2 3\n',
#  'basset_hound_130 4 2 3\n',
#  'basset_hound_131 4 2 3\n',
#  'basset_hound_132 4 2 3\n',
#  'basset_hound_133 4 2 3\n',
#  'basset_hound_134 4 2 3\n',
#  'basset_hound_135 4 2 3\n',
#  'basset_hound_136 4 2 3\n',
#  'basset_hound_137 4 2 3\n',
#  'basset_hound_138 4 2 3\n',
#  'basset_hound_139 4 2 3\n',
#  'basset_hound_13 4 2 3\n',
#  'basset_hound_140 4 2 3\n',
#  'basset_hound_141 4 2 3\n',
#  'basset_hound_142 4 2 3\n',
#  'basset_hound_143 4 2 3\n',
#  'basset_hound_144 4 2 3\n',
#  'basset_hound_145 4 2 3\n',
#  'beagle_100 5 2 4\n',
#  'beagle_101 5 2 4\n',
#  'beagle_102 5 2 4\n',
#  'beagle_103 5 2 4\n',
#  'beagle_104 5 2 4\n',
#  'beagle_105 5 2 4\n',
#  'beagle_107 5 2 4\n',
#  'beagle_108 5 2 4\n',
#  'beagle_109 5 2 4\n',
#  'beagle_10 5 2 4\n',
#  'beagle_110 5 2 4\n',
#  'beagle_111 5 2 4\n',
#  'beagle_112 5 2 4\n',
#  'beagle_113 5 2 4\n',
#  'beagle_114 5 2 4\n',
#  'beagle_115 5 2 4\n',
#  'beagle_116 5 2 4\n',
#  'beagle_117 5 2 4\n',
#  'beagle_118 5 2 4\n',
#  'beagle_119 5 2 4\n',
#  'beagle_120 5 2 4\n',
#  'beagle_121 5 2 4\n',
#  'beagle_122 5 2 4\n',
#  'beagle_123 5 2 4\n',
#  'beagle_124 5 2 4\n',
#  'beagle_125 5 2 4\n',
#  'beagle_126 5 2 4\n',
#  'beagle_127 5 2 4\n',
#  'beagle_128 5 2 4\n',
#  'beagle_129 5 2 4\n',
#  'beagle_12 5 2 4\n',
#  'beagle_130 5 2 4\n',
#  'beagle_131 5 2 4\n',
#  'beagle_133 5 2 4\n',
#  'beagle_134 5 2 4\n',
#  'beagle_135 5 2 4\n',
#  'beagle_136 5 2 4\n',
#  'beagle_137 5 2 4\n',
#  'beagle_138 5 2 4\n',
#  'beagle_139 5 2 4\n',
#  'beagle_13 5 2 4\n',
#  'beagle_140 5 2 4\n',
#  'beagle_141 5 2 4\n',
#  'beagle_142 5 2 4\n',
#  'beagle_143 5 2 4\n',
#  'beagle_144 5 2 4\n',
#  'beagle_145 5 2 4\n',
#  'beagle_146 5 2 4\n',
#  'beagle_147 5 2 4\n',
#  'beagle_148 5 2 4\n',
#  'Bengal_100 6 1 2\n',
#  'Bengal_101 6 1 2\n',
#  'Bengal_102 6 1 2\n',
#  'Bengal_103 6 1 2\n',
#  'Bengal_104 6 1 2\n',
#  'Bengal_105 6 1 2\n',
#  'Bengal_106 6 1 2\n',
#  'Bengal_107 6 1 2\n',
#  'Bengal_108 6 1 2\n',
#  'Bengal_109 6 1 2\n',
#  'Bengal_10 6 1 2\n',
#  'Bengal_110 6 1 2\n',
#  'Bengal_111 6 1 2\n',
#  'Bengal_112 6 1 2\n',
#  'Bengal_113 6 1 2\n',
#  'Bengal_114 6 1 2\n',
#  'Bengal_115 6 1 2\n',
#  'Bengal_116 6 1 2\n',
#  'Bengal_117 6 1 2\n',
#  'Bengal_118 6 1 2\n',
#  'Bengal_119 6 1 2\n',
#  'Bengal_11 6 1 2\n',
#  'Bengal_120 6 1 2\n',
#  'Bengal_121 6 1 2\n',
#  'Bengal_122 6 1 2\n',
#  'Bengal_123 6 1 2\n',
#  'Bengal_124 6 1 2\n',
#  'Bengal_125 6 1 2\n',
#  'Bengal_126 6 1 2\n',
#  'Bengal_127 6 1 2\n',
#  'Bengal_128 6 1 2\n',
#  'Bengal_129 6 1 2\n',
#  'Bengal_12 6 1 2\n',
#  'Bengal_130 6 1 2\n',
#  'Bengal_131 6 1 2\n',
#  'Bengal_132 6 1 2\n',
#  'Bengal_133 6 1 2\n',
#  'Bengal_134 6 1 2\n',
#  'Bengal_135 6 1 2\n',
#  'Bengal_136 6 1 2\n',
#  'Bengal_137 6 1 2\n',
#  'Bengal_138 6 1 2\n',
#  'Bengal_139 6 1 2\n',
#  'Bengal_13 6 1 2\n',
#  'Bengal_140 6 1 2\n',
#  'Bengal_141 6 1 2\n',
#  'Bengal_142 6 1 2\n',
#  'Bengal_143 6 1 2\n',
#  'Bengal_144 6 1 2\n',
#  'Bengal_145 6 1 2\n',
#  'Birman_100 7 1 3\n',
#  'Birman_101 7 1 3\n',
#  'Birman_102 7 1 3\n',
#  'Birman_103 7 1 3\n',
#  'Birman_104 7 1 3\n',
#  'Birman_105 7 1 3\n',
#  'Birman_106 7 1 3\n',
#  'Birman_107 7 1 3\n',
#  'Birman_108 7 1 3\n',
#  'Birman_109 7 1 3\n',
#  'Birman_10 7 1 3\n',
#  'Birman_110 7 1 3\n',
#  'Birman_111 7 1 3\n',
#  'Birman_112 7 1 3\n',
#  'Birman_113 7 1 3\n',
#  'Birman_114 7 1 3\n',
#  'Birman_115 7 1 3\n',
#  'Birman_116 7 1 3\n',
#  'Birman_117 7 1 3\n',
#  'Birman_118 7 1 3\n',
#  'Birman_119 7 1 3\n',
#  'Birman_11 7 1 3\n',
#  'Birman_120 7 1 3\n',
#  'Birman_121 7 1 3\n',
#  'Birman_122 7 1 3\n',
#  'Birman_123 7 1 3\n',
#  'Birman_124 7 1 3\n',
#  'Birman_125 7 1 3\n',
#  'Birman_126 7 1 3\n',
#  'Birman_127 7 1 3\n',
#  'Birman_128 7 1 3\n',
#  'Birman_129 7 1 3\n',
#  'Birman_12 7 1 3\n',
#  'Birman_130 7 1 3\n',
#  'Birman_131 7 1 3\n',
#  'Birman_132 7 1 3\n',
#  'Birman_133 7 1 3\n',
#  'Birman_134 7 1 3\n',
#  'Birman_135 7 1 3\n',
#  'Birman_136 7 1 3\n',
#  'Birman_137 7 1 3\n',
#  'Birman_138 7 1 3\n',
#  'Birman_139 7 1 3\n',
#  'Birman_13 7 1 3\n',
#  'Birman_140 7 1 3\n',
#  'Birman_141 7 1 3\n',
#  'Birman_142 7 1 3\n',
#  'Birman_143 7 1 3\n',
#  'Birman_144 7 1 3\n',
#  'Birman_145 7 1 3\n',
#  'Bombay_100 8 1 4\n',
#  'Bombay_101 8 1 4\n',
#  'Bombay_102 8 1 4\n',
#  'Bombay_103 8 1 4\n',
#  'Bombay_104 8 1 4\n',
#  'Bombay_105 8 1 4\n',
#  'Bombay_106 8 1 4\n',
#  'Bombay_107 8 1 4\n',
#  'Bombay_108 8 1 4\n',
#  'Bombay_109 8 1 4\n',
#  'Bombay_10 8 1 4\n',
#  'Bombay_110 8 1 4\n',
#  'Bombay_111 8 1 4\n',
#  'Bombay_112 8 1 4\n',
#  'Bombay_113 8 1 4\n',
#  'Bombay_114 8 1 4\n',
#  'Bombay_115 8 1 4\n',
#  'Bombay_116 8 1 4\n',
#  'Bombay_117 8 1 4\n',
#  'Bombay_118 8 1 4\n',
#  'Bombay_119 8 1 4\n',
#  'Bombay_120 8 1 4\n',
#  'Bombay_121 8 1 4\n',
#  'Bombay_122 8 1 4\n',
#  'Bombay_123 8 1 4\n',
#  'Bombay_125 8 1 4\n',
#  'Bombay_126 8 1 4\n',
#  'Bombay_127 8 1 4\n',
#  'Bombay_128 8 1 4\n',
#  'Bombay_129 8 1 4\n',
#  'Bombay_12 8 1 4\n',
#  'Bombay_130 8 1 4\n',
#  'Bombay_131 8 1 4\n',
#  'Bombay_132 8 1 4\n',
#  'Bombay_133 8 1 4\n',
#  'Bombay_134 8 1 4\n',
#  'Bombay_135 8 1 4\n',
#  'Bombay_136 8 1 4\n',
#  'Bombay_137 8 1 4\n',
#  'Bombay_138 8 1 4\n',
#  'Bombay_139 8 1 4\n',
#  'Bombay_13 8 1 4\n',
#  'Bombay_140 8 1 4\n',
#  'Bombay_141 8 1 4\n',
#  'Bombay_143 8 1 4\n',
#  'Bombay_144 8 1 4\n',
#  'Bombay_145 8 1 4\n',
#  'Bombay_146 8 1 4\n',
#  'Bombay_148 8 1 4\n',
#  'boxer_100 9 2 5\n',
#  'boxer_101 9 2 5\n',
#  'boxer_102 9 2 5\n',
#  'boxer_103 9 2 5\n',
#  'boxer_104 9 2 5\n',
#  'boxer_105 9 2 5\n',
#  'boxer_106 9 2 5\n',
#  'boxer_107 9 2 5\n',
#  'boxer_108 9 2 5\n',
#  'boxer_109 9 2 5\n',
#  'boxer_10 9 2 5\n',
#  'boxer_110 9 2 5\n',
#  'boxer_111 9 2 5\n',
#  'boxer_112 9 2 5\n',
#  'boxer_113 9 2 5\n',
#  'boxer_114 9 2 5\n',
#  'boxer_115 9 2 5\n',
#  'boxer_116 9 2 5\n',
#  'boxer_117 9 2 5\n',
#  'boxer_118 9 2 5\n',
#  'boxer_119 9 2 5\n',
#  'boxer_11 9 2 5\n',
#  'boxer_120 9 2 5\n',
#  'boxer_121 9 2 5\n',
#  'boxer_122 9 2 5\n',
#  'boxer_123 9 2 5\n',
#  'boxer_124 9 2 5\n',
#  'boxer_125 9 2 5\n',
#  'boxer_126 9 2 5\n',
#  'boxer_127 9 2 5\n',
#  'boxer_128 9 2 5\n',
#  'boxer_129 9 2 5\n',
#  'boxer_12 9 2 5\n',
#  'boxer_130 9 2 5\n',
#  'boxer_131 9 2 5\n',
#  'boxer_132 9 2 5\n',
#  'boxer_133 9 2 5\n',
#  'boxer_134 9 2 5\n',
#  'boxer_135 9 2 5\n',
#  'boxer_136 9 2 5\n',
#  'boxer_137 9 2 5\n',
#  'boxer_138 9 2 5\n',
#  'boxer_139 9 2 5\n',
#  'boxer_13 9 2 5\n',
#  'boxer_140 9 2 5\n',
#  'boxer_141 9 2 5\n',
#  'boxer_142 9 2 5\n',
#  'boxer_143 9 2 5\n',
#  'boxer_144 9 2 5\n',
#  'boxer_145 9 2 5\n',
#  'British_Shorthair_100 10 1 5\n',
#  'British_Shorthair_101 10 1 5\n',
#  'British_Shorthair_102 10 1 5\n',
#  'British_Shorthair_103 10 1 5\n',
#  'British_Shorthair_104 10 1 5\n',
#  'British_Shorthair_105 10 1 5\n',
#  'British_Shorthair_106 10 1 5\n',
#  'British_Shorthair_107 10 1 5\n',
#  'British_Shorthair_108 10 1 5\n',
#  'British_Shorthair_109 10 1 5\n',
#  'British_Shorthair_10 10 1 5\n',
#  'British_Shorthair_110 10 1 5\n',
#  'British_Shorthair_111 10 1 5\n',
#  'British_Shorthair_112 10 1 5\n',
#  'British_Shorthair_113 10 1 5\n',
#  'British_Shorthair_114 10 1 5\n',
#  'British_Shorthair_115 10 1 5\n',
#  'British_Shorthair_116 10 1 5\n',
#  'British_Shorthair_117 10 1 5\n',
#  'British_Shorthair_118 10 1 5\n',
#  'British_Shorthair_119 10 1 5\n',
#  'British_Shorthair_120 10 1 5\n',
#  'British_Shorthair_121 10 1 5\n',
#  'British_Shorthair_122 10 1 5\n',
#  'British_Shorthair_123 10 1 5\n',
#  'British_Shorthair_124 10 1 5\n',
#  'British_Shorthair_125 10 1 5\n',
#  'British_Shorthair_126 10 1 5\n',
#  'British_Shorthair_127 10 1 5\n',
#  'British_Shorthair_128 10 1 5\n',
#  'British_Shorthair_129 10 1 5\n',
#  'British_Shorthair_130 10 1 5\n',
#  'British_Shorthair_133 10 1 5\n',
#  'British_Shorthair_134 10 1 5\n',
#  'British_Shorthair_135 10 1 5\n',
#  'British_Shorthair_136 10 1 5\n',
#  'British_Shorthair_137 10 1 5\n',
#  'British_Shorthair_139 10 1 5\n',
#  'British_Shorthair_140 10 1 5\n',
#  'British_Shorthair_141 10 1 5\n',
#  'British_Shorthair_144 10 1 5\n',
#  'British_Shorthair_145 10 1 5\n',
#  'British_Shorthair_148 10 1 5\n',
#  'British_Shorthair_149 10 1 5\n',
#  'British_Shorthair_151 10 1 5\n',
#  'British_Shorthair_153 10 1 5\n',
#  'British_Shorthair_154 10 1 5\n',
#  'British_Shorthair_155 10 1 5\n',
#  'British_Shorthair_156 10 1 5\n',
#  'British_Shorthair_157 10 1 5\n',
#  'chihuahua_100 11 2 6\n',
#  'chihuahua_101 11 2 6\n',
#  'chihuahua_102 11 2 6\n',
#  'chihuahua_103 11 2 6\n',
#  'chihuahua_104 11 2 6\n',
#  'chihuahua_105 11 2 6\n',
#  'chihuahua_106 11 2 6\n',
#  'chihuahua_107 11 2 6\n',
#  'chihuahua_108 11 2 6\n',
#  'chihuahua_109 11 2 6\n',
#  'chihuahua_10 11 2 6\n',
#  'chihuahua_110 11 2 6\n',
#  'chihuahua_111 11 2 6\n',
#  'chihuahua_112 11 2 6\n',
#  'chihuahua_113 11 2 6\n',
#  'chihuahua_114 11 2 6\n',
#  'chihuahua_115 11 2 6\n',
#  'chihuahua_116 11 2 6\n',
#  'chihuahua_117 11 2 6\n',
#  'chihuahua_118 11 2 6\n',
#  'chihuahua_119 11 2 6\n',
#  'chihuahua_11 11 2 6\n',
#  'chihuahua_120 11 2 6\n',
#  'chihuahua_121 11 2 6\n',
#  'chihuahua_122 11 2 6\n',
#  'chihuahua_123 11 2 6\n',
#  'chihuahua_124 11 2 6\n',
#  'chihuahua_125 11 2 6\n',
#  'chihuahua_126 11 2 6\n',
#  'chihuahua_127 11 2 6\n',
#  'chihuahua_128 11 2 6\n',
#  'chihuahua_129 11 2 6\n',
#  'chihuahua_12 11 2 6\n',
#  'chihuahua_130 11 2 6\n',
#  'chihuahua_131 11 2 6\n',
#  'chihuahua_132 11 2 6\n',
#  'chihuahua_133 11 2 6\n',
#  'chihuahua_134 11 2 6\n',
#  'chihuahua_135 11 2 6\n',
#  'chihuahua_136 11 2 6\n',
#  'chihuahua_137 11 2 6\n',
#  'chihuahua_138 11 2 6\n',
#  'chihuahua_139 11 2 6\n',
#  'chihuahua_13 11 2 6\n',
#  'chihuahua_140 11 2 6\n',
#  'chihuahua_141 11 2 6\n',
#  'chihuahua_142 11 2 6\n',
#  'chihuahua_143 11 2 6\n',
#  'chihuahua_144 11 2 6\n',
#  'chihuahua_145 11 2 6\n',
#  'Egyptian_Mau_100 12 1 6\n',
#  'Egyptian_Mau_101 12 1 6\n',
#  'Egyptian_Mau_102 12 1 6\n',
#  'Egyptian_Mau_103 12 1 6\n',
#  'Egyptian_Mau_104 12 1 6\n',
#  'Egyptian_Mau_105 12 1 6\n',
#  'Egyptian_Mau_106 12 1 6\n',
#  'Egyptian_Mau_107 12 1 6\n',
#  'Egyptian_Mau_108 12 1 6\n',
#  'Egyptian_Mau_109 12 1 6\n',
#  'Egyptian_Mau_10 12 1 6\n',
#  'Egyptian_Mau_110 12 1 6\n',
#  'Egyptian_Mau_111 12 1 6\n',
#  'Egyptian_Mau_112 12 1 6\n',
#  'Egyptian_Mau_113 12 1 6\n',
#  'Egyptian_Mau_114 12 1 6\n',
#  'Egyptian_Mau_115 12 1 6\n',
#  'Egyptian_Mau_116 12 1 6\n',
#  'Egyptian_Mau_117 12 1 6\n',
#  'Egyptian_Mau_118 12 1 6\n',
#  'Egyptian_Mau_119 12 1 6\n',
#  'Egyptian_Mau_11 12 1 6\n',
#  'Egyptian_Mau_120 12 1 6\n',
#  'Egyptian_Mau_121 12 1 6\n',
#  'Egyptian_Mau_122 12 1 6\n',
#  'Egyptian_Mau_123 12 1 6\n',
#  'Egyptian_Mau_124 12 1 6\n',
#  'Egyptian_Mau_125 12 1 6\n',
#  'Egyptian_Mau_126 12 1 6\n',
#  'Egyptian_Mau_127 12 1 6\n',
#  'Egyptian_Mau_128 12 1 6\n',
#  'Egyptian_Mau_12 12 1 6\n',
#  'Egyptian_Mau_130 12 1 6\n',
#  'Egyptian_Mau_131 12 1 6\n',
#  'Egyptian_Mau_132 12 1 6\n',
#  'Egyptian_Mau_133 12 1 6\n',
#  'Egyptian_Mau_134 12 1 6\n',
#  'Egyptian_Mau_136 12 1 6\n',
#  'Egyptian_Mau_138 12 1 6\n',
#  'Egyptian_Mau_13 12 1 6\n',
#  'Egyptian_Mau_140 12 1 6\n',
#  'Egyptian_Mau_141 12 1 6\n',
#  'Egyptian_Mau_142 12 1 6\n',
#  'Egyptian_Mau_143 12 1 6\n',
#  'Egyptian_Mau_144 12 1 6\n',
#  'Egyptian_Mau_146 12 1 6\n',
#  'Egyptian_Mau_147 12 1 6\n',
#  'english_cocker_spaniel_100 13 2 7\n',
#  'english_cocker_spaniel_101 13 2 7\n',
#  'english_cocker_spaniel_102 13 2 7\n',
#  'english_cocker_spaniel_103 13 2 7\n',
#  'english_cocker_spaniel_104 13 2 7\n',
#  'english_cocker_spaniel_105 13 2 7\n',
#  'english_cocker_spaniel_106 13 2 7\n',
#  'english_cocker_spaniel_107 13 2 7\n',
#  'english_cocker_spaniel_108 13 2 7\n',
#  'english_cocker_spaniel_109 13 2 7\n',
#  'english_cocker_spaniel_10 13 2 7\n',
#  'english_cocker_spaniel_110 13 2 7\n',
#  'english_cocker_spaniel_111 13 2 7\n',
#  'english_cocker_spaniel_112 13 2 7\n',
#  'english_cocker_spaniel_113 13 2 7\n',
#  'english_cocker_spaniel_114 13 2 7\n',
#  'english_cocker_spaniel_115 13 2 7\n',
#  'english_cocker_spaniel_116 13 2 7\n',
#  'english_cocker_spaniel_117 13 2 7\n',
#  'english_cocker_spaniel_118 13 2 7\n',
#  'english_cocker_spaniel_119 13 2 7\n',
#  'english_cocker_spaniel_11 13 2 7\n',
#  'english_cocker_spaniel_120 13 2 7\n',
#  'english_cocker_spaniel_121 13 2 7\n',
#  'english_cocker_spaniel_122 13 2 7\n',
#  'english_cocker_spaniel_123 13 2 7\n',
#  'english_cocker_spaniel_124 13 2 7\n',
#  'english_cocker_spaniel_125 13 2 7\n',
#  'english_cocker_spaniel_126 13 2 7\n',
#  'english_cocker_spaniel_127 13 2 7\n',
#  'english_cocker_spaniel_128 13 2 7\n',
#  'english_cocker_spaniel_129 13 2 7\n',
#  'english_cocker_spaniel_12 13 2 7\n',
#  'english_cocker_spaniel_130 13 2 7\n',
#  'english_cocker_spaniel_131 13 2 7\n',
#  'english_cocker_spaniel_132 13 2 7\n',
#  'english_cocker_spaniel_133 13 2 7\n',
#  'english_cocker_spaniel_134 13 2 7\n',
#  'english_cocker_spaniel_135 13 2 7\n',
#  'english_cocker_spaniel_136 13 2 7\n',
#  'english_cocker_spaniel_137 13 2 7\n',
#  'english_cocker_spaniel_138 13 2 7\n',
#  'english_cocker_spaniel_139 13 2 7\n',
#  'english_cocker_spaniel_13 13 2 7\n',
#  'english_cocker_spaniel_140 13 2 7\n',
#  'english_cocker_spaniel_141 13 2 7\n',
#  'english_cocker_spaniel_142 13 2 7\n',
#  'english_cocker_spaniel_143 13 2 7\n',
#  'english_cocker_spaniel_144 13 2 7\n',
#  'english_cocker_spaniel_145 13 2 7\n',
#  'english_setter_100 14 2 8\n',
#  'english_setter_101 14 2 8\n',
#  'english_setter_102 14 2 8\n',
#  'english_setter_103 14 2 8\n',
#  'english_setter_104 14 2 8\n',
#  'english_setter_105 14 2 8\n',
#  'english_setter_106 14 2 8\n',
#  'english_setter_107 14 2 8\n',
#  'english_setter_108 14 2 8\n',
#  'english_setter_109 14 2 8\n',
#  'english_setter_10 14 2 8\n',
#  'english_setter_110 14 2 8\n',
#  'english_setter_111 14 2 8\n',
#  'english_setter_112 14 2 8\n',
#  'english_setter_113 14 2 8\n',
#  'english_setter_114 14 2 8\n',
#  'english_setter_115 14 2 8\n',
#  'english_setter_116 14 2 8\n',
#  'english_setter_117 14 2 8\n',
#  'english_setter_118 14 2 8\n',
#  'english_setter_119 14 2 8\n',
#  'english_setter_11 14 2 8\n',
#  'english_setter_120 14 2 8\n',
#  'english_setter_121 14 2 8\n',
#  'english_setter_122 14 2 8\n',
#  'english_setter_123 14 2 8\n',
#  'english_setter_124 14 2 8\n',
#  'english_setter_125 14 2 8\n',
#  'english_setter_126 14 2 8\n',
#  'english_setter_127 14 2 8\n',
#  'english_setter_128 14 2 8\n',
#  'english_setter_129 14 2 8\n',
#  'english_setter_12 14 2 8\n',
#  'english_setter_130 14 2 8\n',
#  'english_setter_131 14 2 8\n',
#  'english_setter_132 14 2 8\n',
#  'english_setter_133 14 2 8\n',
#  'english_setter_134 14 2 8\n',
#  'english_setter_135 14 2 8\n',
#  'english_setter_136 14 2 8\n',
#  'english_setter_137 14 2 8\n',
#  'english_setter_138 14 2 8\n',
#  'english_setter_139 14 2 8\n',
#  'english_setter_13 14 2 8\n',
#  'english_setter_140 14 2 8\n',
#  'english_setter_141 14 2 8\n',
#  'english_setter_142 14 2 8\n',
#  'english_setter_143 14 2 8\n',
#  'english_setter_144 14 2 8\n',
#  'english_setter_145 14 2 8\n',
#  'german_shorthaired_100 15 2 9\n',
#  'german_shorthaired_101 15 2 9\n',
#  'german_shorthaired_102 15 2 9\n',
#  'german_shorthaired_103 15 2 9\n',
#  'german_shorthaired_104 15 2 9\n',
#  'german_shorthaired_105 15 2 9\n',
#  'german_shorthaired_106 15 2 9\n',
#  'german_shorthaired_107 15 2 9\n',
#  'german_shorthaired_108 15 2 9\n',
#  'german_shorthaired_109 15 2 9\n',
#  'german_shorthaired_10 15 2 9\n',
#  'german_shorthaired_110 15 2 9\n',
#  'german_shorthaired_111 15 2 9\n',
#  'german_shorthaired_112 15 2 9\n',
#  'german_shorthaired_113 15 2 9\n',
#  'german_shorthaired_114 15 2 9\n',
#  'german_shorthaired_115 15 2 9\n',
#  'german_shorthaired_116 15 2 9\n',
#  'german_shorthaired_117 15 2 9\n',
#  'german_shorthaired_118 15 2 9\n',
#  'german_shorthaired_119 15 2 9\n',
#  'german_shorthaired_11 15 2 9\n',
#  'german_shorthaired_120 15 2 9\n',
#  'german_shorthaired_121 15 2 9\n',
#  'german_shorthaired_122 15 2 9\n',
#  'german_shorthaired_123 15 2 9\n',
#  'german_shorthaired_124 15 2 9\n',
#  'german_shorthaired_125 15 2 9\n',
#  'german_shorthaired_126 15 2 9\n',
#  'german_shorthaired_127 15 2 9\n',
#  'german_shorthaired_128 15 2 9\n',
#  'german_shorthaired_129 15 2 9\n',
#  'german_shorthaired_12 15 2 9\n',
#  'german_shorthaired_130 15 2 9\n',
#  'german_shorthaired_131 15 2 9\n',
#  'german_shorthaired_132 15 2 9\n',
#  'german_shorthaired_133 15 2 9\n',
#  'german_shorthaired_134 15 2 9\n',
#  'german_shorthaired_135 15 2 9\n',
#  'german_shorthaired_136 15 2 9\n',
#  'german_shorthaired_137 15 2 9\n',
#  'german_shorthaired_138 15 2 9\n',
#  'german_shorthaired_139 15 2 9\n',
#  'german_shorthaired_13 15 2 9\n',
#  'german_shorthaired_140 15 2 9\n',
#  'german_shorthaired_141 15 2 9\n',
#  'german_shorthaired_142 15 2 9\n',
#  'german_shorthaired_143 15 2 9\n',
#  'german_shorthaired_144 15 2 9\n',
#  'german_shorthaired_145 15 2 9\n',
#  'great_pyrenees_100 16 2 10\n',
#  'great_pyrenees_101 16 2 10\n',
#  'great_pyrenees_102 16 2 10\n',
#  'great_pyrenees_103 16 2 10\n',
#  'great_pyrenees_104 16 2 10\n',
#  'great_pyrenees_105 16 2 10\n',
#  'great_pyrenees_106 16 2 10\n',
#  'great_pyrenees_107 16 2 10\n',
#  'great_pyrenees_108 16 2 10\n',
#  'great_pyrenees_109 16 2 10\n',
#  'great_pyrenees_10 16 2 10\n',
#  'great_pyrenees_110 16 2 10\n',
#  'great_pyrenees_111 16 2 10\n',
#  'great_pyrenees_112 16 2 10\n',
#  'great_pyrenees_113 16 2 10\n',
#  'great_pyrenees_114 16 2 10\n',
#  'great_pyrenees_115 16 2 10\n',
#  'great_pyrenees_116 16 2 10\n',
#  'great_pyrenees_117 16 2 10\n',
#  'great_pyrenees_118 16 2 10\n',
#  'great_pyrenees_119 16 2 10\n',
#  'great_pyrenees_11 16 2 10\n',
#  'great_pyrenees_120 16 2 10\n',
#  'great_pyrenees_121 16 2 10\n',
#  'great_pyrenees_122 16 2 10\n',
#  'great_pyrenees_123 16 2 10\n',
#  'great_pyrenees_124 16 2 10\n',
#  'great_pyrenees_125 16 2 10\n',
#  'great_pyrenees_126 16 2 10\n',
#  'great_pyrenees_127 16 2 10\n',
#  'great_pyrenees_128 16 2 10\n',
#  'great_pyrenees_129 16 2 10\n',
#  'great_pyrenees_12 16 2 10\n',
#  'great_pyrenees_130 16 2 10\n',
#  'great_pyrenees_131 16 2 10\n',
#  'great_pyrenees_132 16 2 10\n',
#  'great_pyrenees_133 16 2 10\n',
#  'great_pyrenees_134 16 2 10\n',
#  'great_pyrenees_135 16 2 10\n',
#  'great_pyrenees_136 16 2 10\n',
#  'great_pyrenees_137 16 2 10\n',
#  'great_pyrenees_138 16 2 10\n',
#  'great_pyrenees_139 16 2 10\n',
#  'great_pyrenees_13 16 2 10\n',
#  'great_pyrenees_140 16 2 10\n',
#  'great_pyrenees_141 16 2 10\n',
#  'great_pyrenees_142 16 2 10\n',
#  'great_pyrenees_143 16 2 10\n',
#  'great_pyrenees_144 16 2 10\n',
#  'great_pyrenees_145 16 2 10\n',
#  'havanese_100 17 2 11\n',
#  'havanese_101 17 2 11\n',
#  'havanese_102 17 2 11\n',
#  'havanese_103 17 2 11\n',
#  'havanese_104 17 2 11\n',
#  'havanese_105 17 2 11\n',
#  'havanese_106 17 2 11\n',
#  'havanese_107 17 2 11\n',
#  'havanese_108 17 2 11\n',
#  'havanese_109 17 2 11\n',
#  'havanese_10 17 2 11\n',
#  'havanese_110 17 2 11\n',
#  'havanese_111 17 2 11\n',
#  'havanese_112 17 2 11\n',
#  'havanese_113 17 2 11\n',
#  'havanese_114 17 2 11\n',
#  'havanese_115 17 2 11\n',
#  'havanese_116 17 2 11\n',
#  'havanese_117 17 2 11\n',
#  'havanese_118 17 2 11\n',
#  'havanese_119 17 2 11\n',
#  'havanese_11 17 2 11\n',
#  'havanese_120 17 2 11\n',
#  'havanese_121 17 2 11\n',
#  'havanese_122 17 2 11\n',
#  'havanese_123 17 2 11\n',
#  'havanese_124 17 2 11\n',
#  'havanese_125 17 2 11\n',
#  'havanese_126 17 2 11\n',
#  'havanese_127 17 2 11\n',
#  'havanese_128 17 2 11\n',
#  'havanese_129 17 2 11\n',
#  'havanese_12 17 2 11\n',
#  'havanese_130 17 2 11\n',
#  'havanese_131 17 2 11\n',
#  'havanese_132 17 2 11\n',
#  'havanese_133 17 2 11\n',
#  'havanese_134 17 2 11\n',
#  'havanese_135 17 2 11\n',
#  'havanese_136 17 2 11\n',
#  'havanese_137 17 2 11\n',
#  'havanese_138 17 2 11\n',
#  'havanese_139 17 2 11\n',
#  'havanese_13 17 2 11\n',
#  'havanese_140 17 2 11\n',
#  'havanese_141 17 2 11\n',
#  'havanese_142 17 2 11\n',
#  'havanese_143 17 2 11\n',
#  'havanese_144 17 2 11\n',
#  'havanese_145 17 2 11\n',
#  'japanese_chin_100 18 2 12\n',
#  'japanese_chin_101 18 2 12\n',
#  'japanese_chin_102 18 2 12\n',
#  'japanese_chin_103 18 2 12\n',
#  'japanese_chin_104 18 2 12\n',
#  'japanese_chin_105 18 2 12\n',
#  'japanese_chin_106 18 2 12\n',
#  'japanese_chin_107 18 2 12\n',
#  'japanese_chin_108 18 2 12\n',
#  'japanese_chin_109 18 2 12\n',
#  'japanese_chin_10 18 2 12\n',
#  'japanese_chin_110 18 2 12\n',
#  'japanese_chin_111 18 2 12\n',
#  'japanese_chin_112 18 2 12\n',
#  'japanese_chin_113 18 2 12\n',
#  'japanese_chin_114 18 2 12\n',
#  'japanese_chin_115 18 2 12\n',
#  'japanese_chin_116 18 2 12\n',
#  'japanese_chin_117 18 2 12\n',
#  'japanese_chin_118 18 2 12\n',
#  'japanese_chin_119 18 2 12\n',
#  'japanese_chin_11 18 2 12\n',
#  'japanese_chin_120 18 2 12\n',
#  'japanese_chin_121 18 2 12\n',
#  'japanese_chin_122 18 2 12\n',
#  'japanese_chin_123 18 2 12\n',
#  'japanese_chin_124 18 2 12\n',
#  'japanese_chin_125 18 2 12\n',
#  'japanese_chin_126 18 2 12\n',
#  'japanese_chin_127 18 2 12\n',
#  'japanese_chin_128 18 2 12\n',
#  'japanese_chin_129 18 2 12\n',
#  'japanese_chin_12 18 2 12\n',
#  'japanese_chin_130 18 2 12\n',
#  'japanese_chin_131 18 2 12\n',
#  'japanese_chin_132 18 2 12\n',
#  'japanese_chin_133 18 2 12\n',
#  'japanese_chin_134 18 2 12\n',
#  'japanese_chin_135 18 2 12\n',
#  'japanese_chin_136 18 2 12\n',
#  'japanese_chin_137 18 2 12\n',
#  'japanese_chin_138 18 2 12\n',
#  'japanese_chin_139 18 2 12\n',
#  'japanese_chin_13 18 2 12\n',
#  'japanese_chin_140 18 2 12\n',
#  'japanese_chin_141 18 2 12\n',
#  'japanese_chin_142 18 2 12\n',
#  'japanese_chin_143 18 2 12\n',
#  'japanese_chin_144 18 2 12\n',
#  'japanese_chin_145 18 2 12\n',
#  'keeshond_100 19 2 13\n',
#  'keeshond_101 19 2 13\n',
#  'keeshond_102 19 2 13\n',
#  'keeshond_103 19 2 13\n',
#  'keeshond_104 19 2 13\n',
#  'keeshond_105 19 2 13\n',
#  'keeshond_106 19 2 13\n',
#  'keeshond_107 19 2 13\n',
#  'keeshond_108 19 2 13\n',
#  'keeshond_109 19 2 13\n',
#  'keeshond_10 19 2 13\n',
#  'keeshond_110 19 2 13\n',
#  'keeshond_111 19 2 13\n',
#  'keeshond_112 19 2 13\n',
#  'keeshond_113 19 2 13\n',
#  'keeshond_114 19 2 13\n',
#  'keeshond_115 19 2 13\n',
#  'keeshond_116 19 2 13\n',
#  'keeshond_117 19 2 13\n',
#  'keeshond_118 19 2 13\n',
#  'keeshond_119 19 2 13\n',
#  'keeshond_11 19 2 13\n',
#  'keeshond_120 19 2 13\n',
#  'keeshond_121 19 2 13\n',
#  'keeshond_122 19 2 13\n',
#  'keeshond_123 19 2 13\n',
#  'keeshond_124 19 2 13\n',
#  'keeshond_125 19 2 13\n',
#  'keeshond_126 19 2 13\n',
#  'keeshond_127 19 2 13\n',
#  'keeshond_128 19 2 13\n',
#  'keeshond_129 19 2 13\n',
#  'keeshond_12 19 2 13\n',
#  'keeshond_130 19 2 13\n',
#  'keeshond_131 19 2 13\n',
#  'keeshond_132 19 2 13\n',
#  'keeshond_133 19 2 13\n',
#  'keeshond_134 19 2 13\n',
#  'keeshond_135 19 2 13\n',
#  'keeshond_136 19 2 13\n',
#  'keeshond_137 19 2 13\n',
#  'keeshond_138 19 2 13\n',
#  'keeshond_139 19 2 13\n',
#  'keeshond_13 19 2 13\n',
#  'keeshond_140 19 2 13\n',
#  'keeshond_141 19 2 13\n',
#  'keeshond_142 19 2 13\n',
#  'keeshond_143 19 2 13\n',
#  'keeshond_144 19 2 13\n',
#  'keeshond_145 19 2 13\n',
#  'leonberger_100 20 2 14\n',
#  'leonberger_101 20 2 14\n',
#  'leonberger_102 20 2 14\n',
#  'leonberger_103 20 2 14\n',
#  'leonberger_104 20 2 14\n',
#  'leonberger_105 20 2 14\n',
#  'leonberger_106 20 2 14\n',
#  'leonberger_107 20 2 14\n',
#  'leonberger_108 20 2 14\n',
#  'leonberger_109 20 2 14\n',
#  'leonberger_10 20 2 14\n',
#  'leonberger_110 20 2 14\n',
#  'leonberger_111 20 2 14\n',
#  'leonberger_112 20 2 14\n',
#  'leonberger_113 20 2 14\n',
#  'leonberger_114 20 2 14\n',
#  'leonberger_115 20 2 14\n',
#  'leonberger_116 20 2 14\n',
#  'leonberger_117 20 2 14\n',
#  'leonberger_118 20 2 14\n',
#  'leonberger_119 20 2 14\n',
#  'leonberger_11 20 2 14\n',
#  'leonberger_120 20 2 14\n',
#  'leonberger_121 20 2 14\n',
#  'leonberger_122 20 2 14\n',
#  'leonberger_123 20 2 14\n',
#  'leonberger_124 20 2 14\n',
#  'leonberger_125 20 2 14\n',
#  'leonberger_126 20 2 14\n',
#  'leonberger_127 20 2 14\n',
#  'leonberger_128 20 2 14\n',
#  'leonberger_129 20 2 14\n',
#  'leonberger_12 20 2 14\n',
#  'leonberger_130 20 2 14\n',
#  'leonberger_131 20 2 14\n',
#  'leonberger_132 20 2 14\n',
#  'leonberger_133 20 2 14\n',
#  'leonberger_134 20 2 14\n',
#  'leonberger_135 20 2 14\n',
#  'leonberger_136 20 2 14\n',
#  'leonberger_137 20 2 14\n',
#  'leonberger_138 20 2 14\n',
#  'leonberger_139 20 2 14\n',
#  'leonberger_13 20 2 14\n',
#  'leonberger_140 20 2 14\n',
#  'leonberger_141 20 2 14\n',
#  'leonberger_142 20 2 14\n',
#  'leonberger_143 20 2 14\n',
#  'leonberger_144 20 2 14\n',
#  'leonberger_145 20 2 14\n',
#  'Maine_Coon_100 21 1 7\n',
#  'Maine_Coon_101 21 1 7\n',
#  'Maine_Coon_102 21 1 7\n',
#  'Maine_Coon_103 21 1 7\n',
#  ...]
