# %%
import torch
from torchvision import datasets, transforms
import torch.nn as nn

# %%
# gpu 할당
if torch.cuda.is_available(): DEVICE = 'cuda' 
else: DEVICE = 'cpu'
BATCH_SIZE = 32
EPOCHS = 30
print('torch version : {}'.format(torch.__version__))
print('torch gpu available : {}'.format(DEVICE))
print('Batch_size : {}'.format(BATCH_SIZE))
print('Epochs : {}'.format(EPOCHS))
# Out:
# torch version : 1.7.1+cu110
# torch gpu available : cuda
# Batch_size : 32
# Epochs : 30

# %%
# CIFAR10 dataset load
train_datasets = datasets.CIFAR10(root='./Data/CIFAR_10/',train = True, download=True, transform = transforms.ToTensor())
test_datasets = datasets.CIFAR10(root='./Data/CIFAR_10/',train = False, download=True, transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(train_datasets, batch_size= BATCH_SIZE,shuffle = True)
test_loader = torch.utils.data.DataLoader(test_datasets, batch_size= BATCH_SIZE,shuffle = False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# check dataset
for image, label in train_loader:
    print('image 크기 : ',image.size())
    print('label 크기 : ',label.size())
    break
# Out:
# image 크기 :  torch.Size([32, 3, 32, 32])
# label 크기 :  torch.Size([32])

# %%
# double check dataset
import matplotlib.pyplot as plt
import numpy as np
pltsize = 2
plt.figure(figsize=(10*pltsize,pltsize))

for i in range(10):
    plt.subplot(1,10,i+1)
    plt.axis('off')
    plt.imshow(np.transpose(image[i],(1,2,0)))
    plt.title('Class : ' + str(label[i].item()))

# %%
import torchvision.models as models
import torch.nn as nn
model = models.resnet101(pretrained=False)

# model.fc.in_features 는 resnet의 fc layer에 연결되는 노드 수에 접근한다.
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs,10)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(),lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

# %%
def train(model,x,optimizer,log_interval):
    model.train()
    
    for idx,(image,label) in enumerate(x):
        image = image.to(DEVICE)
        label = label.to(DEVICE)

        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output,label)
        loss.backward()
        optimizer.step()

        if idx % log_interval == 0:
            print("Train Epoch : {} [ {} / {} ]".format(Epoch,idx * len(image), len(train_loader.dataset)),end = '\t')
            print("Train Loss  : {:.6f}".format(loss.item()))

# %%
def test(model,x):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)

            output = model(image)
            test_loss += criterion(output,label)
            prediction = output.max(1,keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
        
        test_loss /= len(test_loader.dataset)
        test_accuracy = 100. * correct / len(test_loader.dataset)

        return test_loss, test_accuracy

# %%
for Epoch in range(1,EPOCHS+1):
    train(model,train_loader,optimizer,200)
    test_loss, test_accuracy = test(model, test_loader)
    print('[Epoch : {}]] : Test Loss : {}\tTest Accuracy : {}'.format(Epoch,test_loss,test_accuracy))
# Out:
# Train Epoch : 1 [ 0 / 50000 ]	Train Loss  : 1.965546
# Train Epoch : 1 [ 6400 / 50000 ]	Train Loss  : 2.115554
# Train Epoch : 1 [ 12800 / 50000 ]	Train Loss  : 1.421021
# Train Epoch : 1 [ 19200 / 50000 ]	Train Loss  : 1.417743
# Train Epoch : 1 [ 25600 / 50000 ]	Train Loss  : 1.707637
# Train Epoch : 1 [ 32000 / 50000 ]	Train Loss  : 1.516259
# Train Epoch : 1 [ 38400 / 50000 ]	Train Loss  : 2.215621
# Train Epoch : 1 [ 44800 / 50000 ]	Train Loss  : 1.719427
# [Epoch : 1]] : Test Loss : 0.0561382919549942	Test Accuracy : 36.97
# Train Epoch : 2 [ 0 / 50000 ]	Train Loss  : 1.867681
# Train Epoch : 2 [ 6400 / 50000 ]	Train Loss  : 1.888152
# Train Epoch : 2 [ 12800 / 50000 ]	Train Loss  : 1.423285
# Train Epoch : 2 [ 19200 / 50000 ]	Train Loss  : 1.660604
# Train Epoch : 2 [ 25600 / 50000 ]	Train Loss  : 1.626267
# Train Epoch : 2 [ 32000 / 50000 ]	Train Loss  : 1.476713
# Train Epoch : 2 [ 38400 / 50000 ]	Train Loss  : 1.821464
# Train Epoch : 2 [ 44800 / 50000 ]	Train Loss  : 1.508378
# [Epoch : 2]] : Test Loss : 0.10376828163862228	Test Accuracy : 35.54
# Train Epoch : 3 [ 0 / 50000 ]	Train Loss  : 1.709156
# Train Epoch : 3 [ 6400 / 50000 ]	Train Loss  : 1.587053
# Train Epoch : 3 [ 12800 / 50000 ]	Train Loss  : 2.226650
# Train Epoch : 3 [ 19200 / 50000 ]	Train Loss  : 1.634096
# Train Epoch : 3 [ 25600 / 50000 ]	Train Loss  : 1.858685
# Train Epoch : 3 [ 32000 / 50000 ]	Train Loss  : 1.655967
# Train Epoch : 3 [ 38400 / 50000 ]	Train Loss  : 1.680341
# Train Epoch : 3 [ 44800 / 50000 ]	Train Loss  : 1.846070
# [Epoch : 3]] : Test Loss : 0.11811075359582901	Test Accuracy : 33.79
# Train Epoch : 4 [ 0 / 50000 ]	Train Loss  : 1.886285
# Train Epoch : 4 [ 6400 / 50000 ]	Train Loss  : 1.382707
# Train Epoch : 4 [ 12800 / 50000 ]	Train Loss  : 1.623950
# Train Epoch : 4 [ 19200 / 50000 ]	Train Loss  : 1.378133
# Train Epoch : 4 [ 25600 / 50000 ]	Train Loss  : 1.436121
# Train Epoch : 4 [ 32000 / 50000 ]	Train Loss  : 1.719294
# Train Epoch : 4 [ 38400 / 50000 ]	Train Loss  : 1.259428
# Train Epoch : 4 [ 44800 / 50000 ]	Train Loss  : 1.627904
# [Epoch : 4]] : Test Loss : 0.05279327929019928	Test Accuracy : 48.17
# Train Epoch : 5 [ 0 / 50000 ]	Train Loss  : 1.311421
# Train Epoch : 5 [ 6400 / 50000 ]	Train Loss  : 1.570675
# Train Epoch : 5 [ 12800 / 50000 ]	Train Loss  : 1.865939
# Train Epoch : 5 [ 19200 / 50000 ]	Train Loss  : 1.383568
# Train Epoch : 5 [ 25600 / 50000 ]	Train Loss  : 1.025746
# Train Epoch : 5 [ 32000 / 50000 ]	Train Loss  : 1.484734
# Train Epoch : 5 [ 38400 / 50000 ]	Train Loss  : 1.254017
# Train Epoch : 5 [ 44800 / 50000 ]	Train Loss  : 1.577886
# [Epoch : 5]] : Test Loss : 0.12304839491844177	Test Accuracy : 43.18
# Train Epoch : 6 [ 0 / 50000 ]	Train Loss  : 1.338504
# Train Epoch : 6 [ 6400 / 50000 ]	Train Loss  : 1.495415
# Train Epoch : 6 [ 12800 / 50000 ]	Train Loss  : 1.672626
# Train Epoch : 6 [ 19200 / 50000 ]	Train Loss  : 1.462579
# Train Epoch : 6 [ 25600 / 50000 ]	Train Loss  : 1.666215
# Train Epoch : 6 [ 32000 / 50000 ]	Train Loss  : 1.393836
# Train Epoch : 6 [ 38400 / 50000 ]	Train Loss  : 1.480216
# Train Epoch : 6 [ 44800 / 50000 ]	Train Loss  : 1.327321
# [Epoch : 6]] : Test Loss : 0.04268912598490715	Test Accuracy : 50.16
# Train Epoch : 7 [ 0 / 50000 ]	Train Loss  : 1.345801
# Train Epoch : 7 [ 6400 / 50000 ]	Train Loss  : 1.706272
# Train Epoch : 7 [ 12800 / 50000 ]	Train Loss  : 0.990482
# Train Epoch : 7 [ 19200 / 50000 ]	Train Loss  : 1.440890
# Train Epoch : 7 [ 25600 / 50000 ]	Train Loss  : 1.323717
# Train Epoch : 7 [ 32000 / 50000 ]	Train Loss  : 1.746871
# Train Epoch : 7 [ 38400 / 50000 ]	Train Loss  : 1.704071
# Train Epoch : 7 [ 44800 / 50000 ]	Train Loss  : 1.657487
# [Epoch : 7]] : Test Loss : 0.0741214007139206	Test Accuracy : 46.48
# Train Epoch : 8 [ 0 / 50000 ]	Train Loss  : 1.428663
# Train Epoch : 8 [ 6400 / 50000 ]	Train Loss  : 1.124053
# Train Epoch : 8 [ 12800 / 50000 ]	Train Loss  : 1.699242
# Train Epoch : 8 [ 19200 / 50000 ]	Train Loss  : 1.700930
# Train Epoch : 8 [ 25600 / 50000 ]	Train Loss  : 1.261587
# Train Epoch : 8 [ 32000 / 50000 ]	Train Loss  : 1.182824
# Train Epoch : 8 [ 38400 / 50000 ]	Train Loss  : 1.330542
# Train Epoch : 8 [ 44800 / 50000 ]	Train Loss  : 1.999737
# [Epoch : 8]] : Test Loss : 0.12782086431980133	Test Accuracy : 45.46
# Train Epoch : 9 [ 0 / 50000 ]	Train Loss  : 1.467027
# Train Epoch : 9 [ 6400 / 50000 ]	Train Loss  : 1.348831
# Train Epoch : 9 [ 12800 / 50000 ]	Train Loss  : 1.680827
# Train Epoch : 9 [ 19200 / 50000 ]	Train Loss  : 1.322978
# Train Epoch : 9 [ 25600 / 50000 ]	Train Loss  : 1.347766
# Train Epoch : 9 [ 32000 / 50000 ]	Train Loss  : 1.671889
# Train Epoch : 9 [ 38400 / 50000 ]	Train Loss  : 1.448092
# Train Epoch : 9 [ 44800 / 50000 ]	Train Loss  : 1.185246
# [Epoch : 9]] : Test Loss : 0.050867680460214615	Test Accuracy : 51.21
# Train Epoch : 10 [ 0 / 50000 ]	Train Loss  : 1.007448
# Train Epoch : 10 [ 6400 / 50000 ]	Train Loss  : 1.051371
# Train Epoch : 10 [ 12800 / 50000 ]	Train Loss  : 1.126340
# Train Epoch : 10 [ 19200 / 50000 ]	Train Loss  : 1.752968
# Train Epoch : 10 [ 25600 / 50000 ]	Train Loss  : 1.012941
# Train Epoch : 10 [ 32000 / 50000 ]	Train Loss  : 1.172806
# Train Epoch : 10 [ 38400 / 50000 ]	Train Loss  : 1.327092
# Train Epoch : 10 [ 44800 / 50000 ]	Train Loss  : 1.173528
# [Epoch : 10]] : Test Loss : 0.6344882845878601	Test Accuracy : 53.62
# Train Epoch : 11 [ 0 / 50000 ]	Train Loss  : 1.216186
# Train Epoch : 11 [ 6400 / 50000 ]	Train Loss  : 1.414343
# Train Epoch : 11 [ 12800 / 50000 ]	Train Loss  : 1.736034
# Train Epoch : 11 [ 19200 / 50000 ]	Train Loss  : 1.220637
# Train Epoch : 11 [ 25600 / 50000 ]	Train Loss  : 1.578698
# Train Epoch : 11 [ 32000 / 50000 ]	Train Loss  : 1.115937
# Train Epoch : 11 [ 38400 / 50000 ]	Train Loss  : 1.159073
# Train Epoch : 11 [ 44800 / 50000 ]	Train Loss  : 1.274444
# [Epoch : 11]] : Test Loss : 0.08678895980119705	Test Accuracy : 57.38
# Train Epoch : 12 [ 0 / 50000 ]	Train Loss  : 1.091050
# Train Epoch : 12 [ 6400 / 50000 ]	Train Loss  : 1.184855
# Train Epoch : 12 [ 12800 / 50000 ]	Train Loss  : 0.787528
# Train Epoch : 12 [ 19200 / 50000 ]	Train Loss  : 1.081684
# Train Epoch : 12 [ 25600 / 50000 ]	Train Loss  : 1.198501
# Train Epoch : 12 [ 32000 / 50000 ]	Train Loss  : 1.360037
# Train Epoch : 12 [ 38400 / 50000 ]	Train Loss  : 1.226220
# Train Epoch : 12 [ 44800 / 50000 ]	Train Loss  : 0.969204
# [Epoch : 12]] : Test Loss : 0.03622112795710564	Test Accuracy : 61.51
# Train Epoch : 13 [ 0 / 50000 ]	Train Loss  : 1.183625
# Train Epoch : 13 [ 6400 / 50000 ]	Train Loss  : 1.201045
# Train Epoch : 13 [ 12800 / 50000 ]	Train Loss  : 1.000485
# Train Epoch : 13 [ 19200 / 50000 ]	Train Loss  : 1.121055
# Train Epoch : 13 [ 25600 / 50000 ]	Train Loss  : 0.675173
# Train Epoch : 13 [ 32000 / 50000 ]	Train Loss  : 0.976083
# Train Epoch : 13 [ 38400 / 50000 ]	Train Loss  : 0.878676
# Train Epoch : 13 [ 44800 / 50000 ]	Train Loss  : 1.260980
# [Epoch : 13]] : Test Loss : 0.5919046998023987	Test Accuracy : 55.57
# Train Epoch : 14 [ 0 / 50000 ]	Train Loss  : 1.140123
# Train Epoch : 14 [ 6400 / 50000 ]	Train Loss  : 0.967921
# Train Epoch : 14 [ 12800 / 50000 ]	Train Loss  : 0.881314
# Train Epoch : 14 [ 19200 / 50000 ]	Train Loss  : 1.255894
# Train Epoch : 14 [ 25600 / 50000 ]	Train Loss  : 0.984878
# Train Epoch : 14 [ 32000 / 50000 ]	Train Loss  : 0.826000
# Train Epoch : 14 [ 38400 / 50000 ]	Train Loss  : 0.908839
# Train Epoch : 14 [ 44800 / 50000 ]	Train Loss  : 1.438019
# [Epoch : 14]] : Test Loss : 1.4327278137207031	Test Accuracy : 62.89
# Train Epoch : 15 [ 0 / 50000 ]	Train Loss  : 1.053100
# Train Epoch : 15 [ 6400 / 50000 ]	Train Loss  : 0.944966
# Train Epoch : 15 [ 12800 / 50000 ]	Train Loss  : 0.912733
# Train Epoch : 15 [ 19200 / 50000 ]	Train Loss  : 1.041198
# Train Epoch : 15 [ 25600 / 50000 ]	Train Loss  : 0.898771
# Train Epoch : 15 [ 32000 / 50000 ]	Train Loss  : 0.831908
# Train Epoch : 15 [ 38400 / 50000 ]	Train Loss  : 0.908667
# Train Epoch : 15 [ 44800 / 50000 ]	Train Loss  : 1.130980
# [Epoch : 15]] : Test Loss : 2.4535677433013916	Test Accuracy : 64.67
# Train Epoch : 16 [ 0 / 50000 ]	Train Loss  : 0.727625
# Train Epoch : 16 [ 6400 / 50000 ]	Train Loss  : 0.869619
# Train Epoch : 16 [ 12800 / 50000 ]	Train Loss  : 0.614897
# Train Epoch : 16 [ 19200 / 50000 ]	Train Loss  : 0.709151
# Train Epoch : 16 [ 25600 / 50000 ]	Train Loss  : 1.112093
# Train Epoch : 16 [ 32000 / 50000 ]	Train Loss  : 0.595083
# Train Epoch : 16 [ 38400 / 50000 ]	Train Loss  : 0.579416
# Train Epoch : 16 [ 44800 / 50000 ]	Train Loss  : 1.255057
# [Epoch : 16]] : Test Loss : 0.7652466893196106	Test Accuracy : 67.95
# Train Epoch : 17 [ 0 / 50000 ]	Train Loss  : 1.069372
# Train Epoch : 17 [ 6400 / 50000 ]	Train Loss  : 0.698154
# Train Epoch : 17 [ 12800 / 50000 ]	Train Loss  : 0.600491
# Train Epoch : 17 [ 19200 / 50000 ]	Train Loss  : 0.898763
# Train Epoch : 17 [ 25600 / 50000 ]	Train Loss  : 0.652887
# Train Epoch : 17 [ 32000 / 50000 ]	Train Loss  : 1.236442
# Train Epoch : 17 [ 38400 / 50000 ]	Train Loss  : 0.491881
# Train Epoch : 17 [ 44800 / 50000 ]	Train Loss  : 0.841598
# [Epoch : 17]] : Test Loss : 0.14041051268577576	Test Accuracy : 68.96
# Train Epoch : 18 [ 0 / 50000 ]	Train Loss  : 0.553996
# Train Epoch : 18 [ 6400 / 50000 ]	Train Loss  : 1.272174
# Train Epoch : 18 [ 12800 / 50000 ]	Train Loss  : 0.896075
# Train Epoch : 18 [ 19200 / 50000 ]	Train Loss  : 0.781079
# Train Epoch : 18 [ 25600 / 50000 ]	Train Loss  : 0.784343
# Train Epoch : 18 [ 32000 / 50000 ]	Train Loss  : 0.608904
# Train Epoch : 18 [ 38400 / 50000 ]	Train Loss  : 0.867407
# Train Epoch : 18 [ 44800 / 50000 ]	Train Loss  : 0.802248
# [Epoch : 18]] : Test Loss : 0.027145229279994965	Test Accuracy : 70.68
# Train Epoch : 19 [ 0 / 50000 ]	Train Loss  : 0.911686
# Train Epoch : 19 [ 6400 / 50000 ]	Train Loss  : 1.064687
# Train Epoch : 19 [ 12800 / 50000 ]	Train Loss  : 0.369296
# Train Epoch : 19 [ 19200 / 50000 ]	Train Loss  : 0.631307
# Train Epoch : 19 [ 25600 / 50000 ]	Train Loss  : 0.384910
# Train Epoch : 19 [ 32000 / 50000 ]	Train Loss  : 0.397417
# Train Epoch : 19 [ 38400 / 50000 ]	Train Loss  : 0.754782
# Train Epoch : 19 [ 44800 / 50000 ]	Train Loss  : 0.981444
# [Epoch : 19]] : Test Loss : 0.04000380262732506	Test Accuracy : 70.68
# Train Epoch : 20 [ 0 / 50000 ]	Train Loss  : 0.660951
# Train Epoch : 20 [ 6400 / 50000 ]	Train Loss  : 0.552142
# Train Epoch : 20 [ 12800 / 50000 ]	Train Loss  : 0.262760
# Train Epoch : 20 [ 19200 / 50000 ]	Train Loss  : 0.786645
# Train Epoch : 20 [ 25600 / 50000 ]	Train Loss  : 0.469011
# Train Epoch : 20 [ 32000 / 50000 ]	Train Loss  : 0.889841
# Train Epoch : 20 [ 38400 / 50000 ]	Train Loss  : 0.738457
# Train Epoch : 20 [ 44800 / 50000 ]	Train Loss  : 0.569243
# [Epoch : 20]] : Test Loss : 0.029752828180789948	Test Accuracy : 69.67
# Train Epoch : 21 [ 0 / 50000 ]	Train Loss  : 0.448684
# Train Epoch : 21 [ 6400 / 50000 ]	Train Loss  : 0.427656
# Train Epoch : 21 [ 12800 / 50000 ]	Train Loss  : 0.174399
# Train Epoch : 21 [ 19200 / 50000 ]	Train Loss  : 0.334547
# Train Epoch : 21 [ 25600 / 50000 ]	Train Loss  : 0.483032
# Train Epoch : 21 [ 32000 / 50000 ]	Train Loss  : 0.444140
# Train Epoch : 21 [ 38400 / 50000 ]	Train Loss  : 0.330600
# Train Epoch : 21 [ 44800 / 50000 ]	Train Loss  : 0.227668
# [Epoch : 21]] : Test Loss : 0.026636769995093346	Test Accuracy : 73.0
# Train Epoch : 22 [ 0 / 50000 ]	Train Loss  : 0.582405
# Train Epoch : 22 [ 6400 / 50000 ]	Train Loss  : 0.695448
# Train Epoch : 22 [ 12800 / 50000 ]	Train Loss  : 0.679768
# Train Epoch : 22 [ 19200 / 50000 ]	Train Loss  : 0.378311
# Train Epoch : 22 [ 25600 / 50000 ]	Train Loss  : 0.635174
# Train Epoch : 22 [ 32000 / 50000 ]	Train Loss  : 0.536128
# Train Epoch : 22 [ 38400 / 50000 ]	Train Loss  : 0.748255
# Train Epoch : 22 [ 44800 / 50000 ]	Train Loss  : 0.759156
# [Epoch : 22]] : Test Loss : 0.031267695128917694	Test Accuracy : 70.06
# Train Epoch : 23 [ 0 / 50000 ]	Train Loss  : 0.618540
# Train Epoch : 23 [ 6400 / 50000 ]	Train Loss  : 0.555484
# Train Epoch : 23 [ 12800 / 50000 ]	Train Loss  : 0.275950
# Train Epoch : 23 [ 19200 / 50000 ]	Train Loss  : 0.368316
# Train Epoch : 23 [ 25600 / 50000 ]	Train Loss  : 0.616726
# Train Epoch : 23 [ 32000 / 50000 ]	Train Loss  : 0.399454
# Train Epoch : 23 [ 38400 / 50000 ]	Train Loss  : 0.401806
# Train Epoch : 23 [ 44800 / 50000 ]	Train Loss  : 0.479423
# [Epoch : 23]] : Test Loss : 0.029726985841989517	Test Accuracy : 72.57
# Train Epoch : 24 [ 0 / 50000 ]	Train Loss  : 0.278938
# Train Epoch : 24 [ 6400 / 50000 ]	Train Loss  : 0.298454
# Train Epoch : 24 [ 12800 / 50000 ]	Train Loss  : 0.210869
# Train Epoch : 24 [ 19200 / 50000 ]	Train Loss  : 0.425287
# Train Epoch : 24 [ 25600 / 50000 ]	Train Loss  : 0.247217
# Train Epoch : 24 [ 32000 / 50000 ]	Train Loss  : 0.471811
# Train Epoch : 24 [ 38400 / 50000 ]	Train Loss  : 0.531901
# Train Epoch : 24 [ 44800 / 50000 ]	Train Loss  : 0.659142
# [Epoch : 24]] : Test Loss : 0.03212982043623924	Test Accuracy : 71.27
# Train Epoch : 25 [ 0 / 50000 ]	Train Loss  : 0.329070
# Train Epoch : 25 [ 6400 / 50000 ]	Train Loss  : 0.369993
# Train Epoch : 25 [ 12800 / 50000 ]	Train Loss  : 0.152749
# Train Epoch : 25 [ 19200 / 50000 ]	Train Loss  : 0.376533
# Train Epoch : 25 [ 25600 / 50000 ]	Train Loss  : 0.768028
# Train Epoch : 25 [ 32000 / 50000 ]	Train Loss  : 0.301272
# Train Epoch : 25 [ 38400 / 50000 ]	Train Loss  : 0.183655
# Train Epoch : 25 [ 44800 / 50000 ]	Train Loss  : 0.217284
# [Epoch : 25]] : Test Loss : 0.03198656439781189	Test Accuracy : 72.57
# Train Epoch : 26 [ 0 / 50000 ]	Train Loss  : 0.088853
# Train Epoch : 26 [ 6400 / 50000 ]	Train Loss  : 0.197637
# Train Epoch : 26 [ 12800 / 50000 ]	Train Loss  : 0.178882
# Train Epoch : 26 [ 19200 / 50000 ]	Train Loss  : 0.495735
# Train Epoch : 26 [ 25600 / 50000 ]	Train Loss  : 1.291508
# Train Epoch : 26 [ 32000 / 50000 ]	Train Loss  : 0.640045
# Train Epoch : 26 [ 38400 / 50000 ]	Train Loss  : 0.321680
# Train Epoch : 26 [ 44800 / 50000 ]	Train Loss  : 0.408729
# [Epoch : 26]] : Test Loss : 0.033564820885658264	Test Accuracy : 71.21
# Train Epoch : 27 [ 0 / 50000 ]	Train Loss  : 0.139338
# Train Epoch : 27 [ 6400 / 50000 ]	Train Loss  : 0.173931
# Train Epoch : 27 [ 12800 / 50000 ]	Train Loss  : 0.126455
# Train Epoch : 27 [ 19200 / 50000 ]	Train Loss  : 0.279490
# Train Epoch : 27 [ 25600 / 50000 ]	Train Loss  : 0.439495
# Train Epoch : 27 [ 32000 / 50000 ]	Train Loss  : 0.167385
# Train Epoch : 27 [ 38400 / 50000 ]	Train Loss  : 0.096456
# Train Epoch : 27 [ 44800 / 50000 ]	Train Loss  : 0.358136
# [Epoch : 27]] : Test Loss : 0.03533843159675598	Test Accuracy : 71.84
# Train Epoch : 28 [ 0 / 50000 ]	Train Loss  : 0.257303
# Train Epoch : 28 [ 6400 / 50000 ]	Train Loss  : 0.160001
# Train Epoch : 28 [ 12800 / 50000 ]	Train Loss  : 0.068828
# Train Epoch : 28 [ 19200 / 50000 ]	Train Loss  : 0.156237
# Train Epoch : 28 [ 25600 / 50000 ]	Train Loss  : 0.109736
# Train Epoch : 28 [ 32000 / 50000 ]	Train Loss  : 0.267660
# Train Epoch : 28 [ 38400 / 50000 ]	Train Loss  : 0.114581
# Train Epoch : 28 [ 44800 / 50000 ]	Train Loss  : 0.304366
# [Epoch : 28]] : Test Loss : 0.03473827615380287	Test Accuracy : 72.71
# Train Epoch : 29 [ 0 / 50000 ]	Train Loss  : 0.139427
# Train Epoch : 29 [ 6400 / 50000 ]	Train Loss  : 0.164799
# Train Epoch : 29 [ 12800 / 50000 ]	Train Loss  : 0.370197
# Train Epoch : 29 [ 19200 / 50000 ]	Train Loss  : 0.116809
# Train Epoch : 29 [ 25600 / 50000 ]	Train Loss  : 0.177566
# Train Epoch : 29 [ 32000 / 50000 ]	Train Loss  : 0.175566
# Train Epoch : 29 [ 38400 / 50000 ]	Train Loss  : 0.236018
# Train Epoch : 29 [ 44800 / 50000 ]	Train Loss  : 0.221719
# [Epoch : 29]] : Test Loss : 0.036320365965366364	Test Accuracy : 72.71
# Train Epoch : 30 [ 0 / 50000 ]	Train Loss  : 0.071901
# Train Epoch : 30 [ 6400 / 50000 ]	Train Loss  : 0.778377
# Train Epoch : 30 [ 12800 / 50000 ]	Train Loss  : 0.433436
# Train Epoch : 30 [ 19200 / 50000 ]	Train Loss  : 0.069124
# Train Epoch : 30 [ 25600 / 50000 ]	Train Loss  : 0.269368
# Train Epoch : 30 [ 32000 / 50000 ]	Train Loss  : 0.030782
# Train Epoch : 30 [ 38400 / 50000 ]	Train Loss  : 0.062600
# Train Epoch : 30 [ 44800 / 50000 ]	Train Loss  : 0.202503
# [Epoch : 30]] : Test Loss : 0.03486205264925957	Test Accuracy : 72.81
